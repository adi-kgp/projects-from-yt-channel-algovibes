# %% [markdown]
# ### Time Series Momentum Trading Strategy
#
# * If the asset was rising by a certain % buy it, hold it, then sell it
#
# * In specific, if it was rising by 5% over the last 20 days, hold it for 10 days

# %%
import yfinance as yf
import pandas as pd

# %%
df = yf.download('AAPL', start='2020-01-01', end='2024-05-01')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   72.960472
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.251152
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   72.826859
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.484360
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   73.650352
# ...                ...         ...         ...         ...         ...
# 2024-04-24  166.539993  169.300003  166.210007  169.020004  168.791061
# 2024-04-25  169.529999  170.610001  168.149994  169.889999  169.659882
# 2024-04-26  169.880005  171.339996  169.179993  169.300003  169.070679
# 2024-04-29  173.369995  176.029999  173.100006  173.500000  173.264984
# 2024-04-30  173.330002  174.990005  170.000000  170.330002  170.099289
#
#                Volume
# Date
# 2020-01-02  135480400
# 2020-01-03  146322800
# 2020-01-06  118387200
# 2020-01-07  108872000
# 2020-01-08  132079200
# ...               ...
# 2024-04-24   48251800
# 2024-04-25   50558300
# 2024-04-26   44838400
# 2024-04-29   68169400
# 2024-04-30   65934800
#
# [1089 rows x 6 columns]

# %%
df['ret_20'] = df.Close.pct_change(20)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   72.960472
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.251152
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   72.826859
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.484360
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   73.650352
# ...                ...         ...         ...         ...         ...
# 2024-04-24  166.539993  169.300003  166.210007  169.020004  168.791061
# 2024-04-25  169.529999  170.610001  168.149994  169.889999  169.659882
# 2024-04-26  169.880005  171.339996  169.179993  169.300003  169.070679
# 2024-04-29  173.369995  176.029999  173.100006  173.500000  173.264984
# 2024-04-30  173.330002  174.990005  170.000000  170.330002  170.099289
#
#                Volume    ret_20
# Date
# 2020-01-02  135480400       NaN
# 2020-01-03  146322800       NaN
# 2020-01-06  118387200       NaN
# 2020-01-07  108872000       NaN
# 2020-01-08  132079200       NaN
# ...               ...       ...
# 2024-04-24   48251800 -0.004066
# 2024-04-25   50558300 -0.019733
# 2024-04-26   44838400 -0.012713
# 2024-04-29   68169400  0.020408
# 2024-04-30   65934800  0.008825
#
# [1089 rows x 7 columns]

# %%
df.dropna(inplace=True)

# %%
df['signal'] = df.ret_20 > 0.05
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-31   80.232498   80.669998   77.072502   77.377502   75.185585
# 2020-02-03   76.074997   78.372498   75.555000   77.165001   74.979126
# 2020-02-04   78.827499   79.910004   78.407501   79.712502   77.454453
# 2020-02-05   80.879997   81.190002   79.737503   80.362503   78.086052
# 2020-02-06   80.642502   81.305000   80.065002   81.302498   78.999397
# ...                ...         ...         ...         ...         ...
# 2024-04-24  166.539993  169.300003  166.210007  169.020004  168.791061
# 2024-04-25  169.529999  170.610001  168.149994  169.889999  169.659882
# 2024-04-26  169.880005  171.339996  169.179993  169.300003  169.070679
# 2024-04-29  173.369995  176.029999  173.100006  173.500000  173.264984
# 2024-04-30  173.330002  174.990005  170.000000  170.330002  170.099289
#
#                Volume    ret_20  signal
# Date
# 2020-01-31  199588400  0.030498   False
# 2020-02-03  173788400  0.037757   False
# 2020-02-04  136616400  0.063542    True
# 2020-02-05  118826800  0.077281    True
# 2020-02-06  105425600  0.072628    True
# ...               ...       ...     ...
# 2024-04-24   48251800 -0.004066   False
# 2024-04-25   50558300 -0.019733   False
# 2024-04-26   44838400 -0.012713   False
# 2024-04-29   68169400  0.020408   False
# 2024-04-30   65934800  0.008825   False
#
# [1069 rows x 8 columns]

# %%
df['buyprice'] = df.Open.shift(-1)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-31   80.232498   80.669998   77.072502   77.377502   75.185585
# 2020-02-03   76.074997   78.372498   75.555000   77.165001   74.979126
# 2020-02-04   78.827499   79.910004   78.407501   79.712502   77.454453
# 2020-02-05   80.879997   81.190002   79.737503   80.362503   78.086052
# 2020-02-06   80.642502   81.305000   80.065002   81.302498   78.999397
# ...                ...         ...         ...         ...         ...
# 2024-04-24  166.539993  169.300003  166.210007  169.020004  168.791061
# 2024-04-25  169.529999  170.610001  168.149994  169.889999  169.659882
# 2024-04-26  169.880005  171.339996  169.179993  169.300003  169.070679
# 2024-04-29  173.369995  176.029999  173.100006  173.500000  173.264984
# 2024-04-30  173.330002  174.990005  170.000000  170.330002  170.099289
#
#                Volume    ret_20  signal    buyprice
# Date
# 2020-01-31  199588400  0.030498   False   76.074997
# 2020-02-03  173788400  0.037757   False   78.827499
# 2020-02-04  136616400  0.063542    True   80.879997
# 2020-02-05  118826800  0.077281    True   80.642502
# 2020-02-06  105425600  0.072628    True   80.592499
# ...               ...       ...     ...         ...
# 2024-04-24   48251800 -0.004066   False  169.529999
# 2024-04-25   50558300 -0.019733   False  169.880005
# 2024-04-26   44838400 -0.012713   False  173.369995
# 2024-04-29   68169400  0.020408   False  173.330002
# 2024-04-30   65934800  0.008825   False         NaN
#
# [1069 rows x 9 columns]

# %%
# df.loc['2020-02-04':][5:6]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2020-02-11  80.900002  80.974998  79.677498  79.902496  77.823318  94323200
#
#               ret_20  signal  buyprice
# Date
# 2020-02-11  0.008361   False   80.3675

# %%
# df.loc['2020-02-04':].head(6)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-02-04  78.827499  79.910004  78.407501  79.712502  77.454453  136616400
# 2020-02-05  80.879997  81.190002  79.737503  80.362503  78.086052  118826800
# 2020-02-06  80.642502  81.305000  80.065002  81.302498  78.999397  105425600
# 2020-02-07  80.592499  80.849998  79.500000  80.007500  77.925598  117684000
# 2020-02-10  78.544998  80.387497  78.462502  80.387497  78.295700  109348800
# 2020-02-11  80.900002  80.974998  79.677498  79.902496  77.823318   94323200
#
#               ret_20  signal   buyprice
# Date
# 2020-02-04  0.063542    True  80.879997
# 2020-02-05  0.077281    True  80.642502
# 2020-02-06  0.072628    True  80.592499
# 2020-02-07  0.033588   False  78.544998
# 2020-02-10  0.036155   False  80.900002
# 2020-02-11  0.008361   False  80.367500

# %%
profits = []
in_position = False
sellidx = pd.to_datetime('1900-01-01')

for index, row in df.iterrows():
    if not in_position and row.signal and index > sellidx:
        buyprice = df.loc[index:][0:1].buyprice.values[0]
        in_position = True
    if in_position:
        sellprice = df.loc[index:][5:6].Close.values[0]
        sellidx = df.loc[index:][5:6].index
        profit = (sellprice - buyprice)/buyprice
        profits.append(profit)
        in_position = False

# %%
profits
# Out:
# [-0.01208581786253751,
#  0.054004660155127705,
#  0.024938521351093205,
#  0.0450601836027804,
#  0.014609830017634011,
#  0.0549359069908368,
#  -0.0051004448113891035,
#  0.059539168219758146,
#  0.006527150082254444,
#  0.028761508200264973,
#  0.05831565775942144,
#  0.0305532218314095,
#  0.007352741327872168,
#  0.15439637213771887,
#  -2.287894082780472e-05,
#  0.01116399837877867,
#  0.04819205814953377,
#  -0.05188903160033216,
#  -0.06837822628114687,
#  -0.07415976319216264,
#  -0.0005999802513312368,
#  0.022642738743900694,
#  0.026901136328269452,
#  0.015981481108813284,
#  -0.034181667611681316,
#  0.008456011750175442,
#  0.046406666084157354,
#  -0.07765429539102899,
#  -0.016163095173290287,
#  -0.07004210722866099,
#  0.0683461076021704,
#  -0.0023913264587068594,
#  0.009987833148101923,
#  -0.013859335544648313,
#  0.0206563905558712,
#  0.049096790884941115,
#  0.014630111479310648,
#  -0.025730443951609068,
#  -0.012944789038326085,
#  -0.0015031512693746533,
#  -0.0034612862175336825,
#  0.02639852405753041,
#  -0.041546121844797244,
#  0.004418878276729417,
#  -0.024145689523006313,
#  -0.005328235778062768,
#  0.03331459246235493,
#  0.012781019495932527,
#  -0.020303432699871157,
#  0.0027105482876190034,
#  -0.057164771189187925,
#  0.03922604238064944,
#  -0.010860193086855766,
#  -0.02157548008294428,
#  0.05601786278145763,
#  0.014821963017040857,
#  0.028342792791727096,
#  0.03444137257016824,
#  -0.030153903761356,
#  -0.0502629888475511,
#  -0.09650038146971744,
#  0.015573552033422863,
#  -0.03796440717432575,
#  0.02413225857912937,
#  0.020282098027219878,
#  0.02843570058267418,
#  -0.01517975250081094,
#  -0.010357872716030876,
#  0.01380545870359332,
#  0.02347917598756988,
#  -0.004635787141278376,
#  0.0005218668767935027,
#  -0.019275434595210424,
#  0.0006753538437680297,
#  0.012089668589624642,
#  0.02998799576633807,
#  -0.004957533699444463,
#  -0.0030242265055393574,
#  -0.06422500656435719,
#  0.014852239528783265,
#  -0.004820025108611051,
#  0.030161128093432816,
#  0.009482834272606495]

# %%
pd.Series(profits).plot()
# Out:
# <Axes: >

# %%
(pd.Series(profits) + 1).cumprod().plot()
# Out:
# <Axes: >

# %%
(pd.Series(profits) + 1).prod()-1
# Out:
# 0.3563048433848357
